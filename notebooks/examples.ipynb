# %%
import sys
import os

# Replace with the actual path to your pyxations package
package_path = "../pyxations"
sys.path.append(package_path)
import pyxations as pyx

# %%
# current_folder = os.getcwd()
# current_folder = os.path.dirname(current_folder)
# current_folder
# iles_folder_path = os.path.join(current_folder,"example_files")
# bids_dataset_folder = dataset_to_bids(current_folder,files_folder_path,"example_dataset")

# pyx.dataset_to_bids(
#     target_folder_path=" Path/to/the/folder/where/the/BIDS/dataset/will/be/created",
#     files_folder_path="Path/to/the/folder/containing/the/EDF/files",
#     dataset_name="dataset_name",
# )

# pyx.compute_derivatives_for_dataset(
#     bids_dataset_folder="Path/to/dataset_name",
#     msg_keywords=["start_msg", "end_msg"],  # multiple msg keywords are allowed
# )

# pyx.process_derivatives(
#     derivatives_folder_path="Path/to/dataset_name_derivatives",  # generated by `compute_derivatives_for_dataset`
#     start_msgs=["start_msg"],
#     end_msgs=["end_msg"],
# )

# %%
# Usage example
experiment = pyx.Experiment("../example_dataset_derivatives")
suj = experiment.get_subject_data(
    subject_id="cr03",
    session="first_half",
    trial_id="2",
    detection_algorithm_folder="eyelink_events",
)

# %%
dir(suj)

# %%
type(suj)

# %%
suj.plot_scanpath()
