# %%
import sys
import os

# Replace with the actual path to your pyxations package
package_path = "../pyxations"
sys.path.append(package_path)
import pyxations as pyx

# %%
cr03_first_half = pyx.Session("../example_dataset", "cr03", "first_half")

# %%
cr03_first_half.dataset_path, cr03_first_half.session_id, cr03_first_half.subject_id
# Out:
# ('../example_dataset_derivatives', 'first_half', 'cr03')

# %%
cr03_first_half

# %%
cr03_first_half.load_data("eyelink")

# %%
cr03_first_half.plot_scanpath(detection_algorithm="eyelink", trial_index=7)
