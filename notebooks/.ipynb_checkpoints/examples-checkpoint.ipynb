# %%
import pyxations as pyx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pyxations as pyx
#
# ModuleNotFoundError: No module named 'pyxations'

# %%
# !pip freeze
# Out:
# asttokens==2.4.1
# comm==0.2.2
# debugpy==1.8.5
# decorator==5.1.1
# exceptiongroup==1.2.2
# executing==2.1.0
# ipykernel==6.29.5
# ipython==8.27.0
# jedi==0.19.1
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# matplotlib-inline==0.1.7
# nest-asyncio==1.6.0
# packaging==24.1
# parso==0.8.4
# pexpect==4.9.0
# platformdirs==4.3.2
# prompt_toolkit==3.0.47
# psutil==6.0.0
# ptyprocess==0.7.0
# pure_eval==0.2.3
# Pygments==2.18.0
# python-dateutil==2.9.0.post0
# pyzmq==26.2.0
# six==1.16.0
# stack-data==0.6.3
# tornado==6.4.1
# traitlets==5.14.3
# typing_extensions==4.12.2
# wcwidth==0.2.13

# %%
# Usage example
experiment = pyx.Experiment(derivatives_folder_path="../../example_dataset_derivatives")
data = experiment.get_subject_data(subject_id="0048", session="experimento_condicion", trial_id=2, detection_algorithm_folder="eyelink_events")
print(data.keys())
